# %%
import pandas as pd
import numpy as np
from wrangle import *
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
df = pd.read_csv("Data/aphis_data.csv")
df.sample(5)
# Out:
#       sample_year  sample_month_number sample_month state_code  \
# 6987         2019                    6         June         VT
# 5770         2018                    4        April         UT
# 2063         2013                    7         July         NY
# 583          2011                    8       August         NY
# 4099         2016                    6         June         HI
#
#      sampling_county  varroa_per_100_bees  million_spores_per_bee abpv  \
# 6987        Franklin                 0.11                     0.0    -
# 5770           Davis                 0.00                     0.6    -
# 2063             NaN                 0.25                     0.8    -
# 583              NaN                 0.00                     0.0  NaN
# 4099          Hawaii                 0.00                     4.2    -
#
#      abpv_percentile cbpv  ... iapv_percentile  kbv kbv_percentile lsv2  \
# 6987             NaN    +  ...             NaN    -            NaN    -
# ...

# %%
df.sample_year.value_counts()
# Out:
# 2018    1061
# 2017     951
# 2016     935
# 2019     798
# 2013     786
# 2015     732
# 2020     728
# 2012     710
# 2011     685
# 2014     599
# 2010     294
# 2009      19
# Name: sample_year, dtype: int64

# %%
df[df.state_code == "WA"]
# Out:
#       sample_year  sample_month_number sample_month state_code  \
# 235          2010                    9    September         WA
# 247          2010                    9    September         WA
# 265          2010                    9    September         WA
# 266          2010                    9    September         WA
# 267          2010                    9    September         WA
# ...           ...                  ...          ...        ...
# 7394         2019                    9    September         WA
# 7414         2019                    9    September         WA
# 7510         2019                   10      October         WA
# 7525         2019                   10      October         WA
# 7541         2019                   10      October         WA
#
#      sampling_county  varroa_per_100_bees  million_spores_per_bee abpv  \
# 235              NaN                 0.08                    0.10    +
# ...

# %%
cols = ["sample_year","sample_month_number"]

df['year'] = df[cols].apply(lambda row: '-'.join(row.values.astype(str)), axis=1)

# %%
df.sample()
# Out:
#       sample_year  sample_month_number sample_month state_code  \
# 7702         2020                    6         June         OR
#
#      sampling_county  varroa_per_100_bees  million_spores_per_bee abpv  \
# 7702       Clackamas                 0.44                    0.05    -
#
#      abpv_percentile cbpv  ... kbv kbv_percentile lsv2 lsv2_percentile sbpv  \
# 7702             NaN    -  ...   -            NaN    +              80    -
#
#      sbpv_percentile mkv mkv_percentile pesticides    year
# 7702             NaN   -            NaN        NaN  2020-6
#
# [1 rows x 27 columns]

# %%
df.year = pd.to_datetime(df.year, format='%Y-%m')

# %%
df = df.set_index(df.year).sort_index()

# %%
df.head()
# Out:
#             sample_year  sample_month_number sample_month state_code  \
# year
# 2009-07-01         2009                    7         July         HI
# 2009-07-01         2009                    7         July         HI
# 2009-07-01         2009                    7         July         HI
# 2009-07-01         2009                    7         July         HI
# 2009-07-01         2009                    7         July         HI
#
#            sampling_county  varroa_per_100_bees  million_spores_per_bee abpv  \
# year
# 2009-07-01             NaN                 0.00                    0.02  NaN
# 2009-07-01             NaN                 3.46                    0.03  NaN
# 2009-07-01             NaN                11.48                    0.03  NaN
# 2009-07-01             NaN                14.00                    0.08  NaN
# 2009-07-01             NaN                 1.15                    0.03  NaN
#
# ...

# %%
df.resample("Y").varroa_per_100_bees.mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.resample("m").varroa_per_100_bees.mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.resample('Y').million_spores_per_bee.mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.resample('m').million_spores_per_bee.mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
df.groupby("state_code")[["varroa_per_100_bees"]].sum().sort_values("varroa_per_100_bees", ascending = False).head(9).plot.bar()
# Out:
# <AxesSubplot:xlabel='state_code'>

# %%
df.groupby("state_code")[["varroa_per_100_bees"]].mean().sort_values("varroa_per_100_bees", ascending = False).head(9).plot.bar()
# Out:
# <AxesSubplot:xlabel='state_code'>

# %%
df.head()
# Out:
#             sample_year  sample_month_number sample_month state_code  \
# year
# 2009-07-01         2009                    7         July         HI
# 2009-07-01         2009                    7         July         HI
# 2009-07-01         2009                    7         July         HI
# 2009-07-01         2009                    7         July         HI
# 2009-07-01         2009                    7         July         HI
#
#            sampling_county  varroa_per_100_bees  million_spores_per_bee abpv  \
# year
# 2009-07-01             NaN                 0.00                    0.02  NaN
# 2009-07-01             NaN                 3.46                    0.03  NaN
# 2009-07-01             NaN                11.48                    0.03  NaN
# 2009-07-01             NaN                14.00                    0.08  NaN
# 2009-07-01             NaN                 1.15                    0.03  NaN
#
# ...

# %%
df[df.year.dt.year == 2009].groupby("state_code")[["varroa_per_100_bees", "million_spores_per_bee"]].mean()\
.sort_values(["varroa_per_100_bees","million_spores_per_bee"] , ascending = [False, False])
# Out:
#             varroa_per_100_bees  million_spores_per_bee
# state_code
# HI                     7.344286                0.645714
# CA                     1.830833                0.175000

# %%
df[df.year.dt.year == 2010].groupby("state_code")[["varroa_per_100_bees", "million_spores_per_bee"]].mean()\
.sort_values(["varroa_per_100_bees","million_spores_per_bee"] , ascending = [False, False])
# Out:
#             varroa_per_100_bees  million_spores_per_bee
# state_code
# MI                     7.545200                0.012800
# TN                     7.112500                0.008125
# IN                     4.733600                0.037200
# WA                     4.697500                0.210000
# PA                     4.377600                0.087200
# SD                     4.349200                0.009600
# AL                     3.390800                0.079600
# TX                     3.293636                0.009091
# NY                     2.822500                0.062917
# FL                     2.568333                0.745833
# HI                     2.216364                0.582727
# GA                     1.839600                0.028400
# CA                     1.282424                0.759394

# %%
df[df.year.dt.year == 2011].groupby("state_code")[["varroa_per_100_bees", "million_spores_per_bee"]].mean()\
.sort_values(["varroa_per_100_bees","million_spores_per_bee"] , ascending = [False, False]).plot.bar()
# Out:
# <AxesSubplot:xlabel='state_code'>

# %%
plt.figure(figsize= (20,10))
df[df.year.dt.year == 2011].groupby("state_code")[["varroa_per_100_bees", "million_spores_per_bee"]].mean()\
.sort_values(["varroa_per_100_bees","million_spores_per_bee"] , ascending = [False, False]).plot.bar()
# Out:
# <AxesSubplot:xlabel='state_code'>

# %%
df[df.year.dt.year == 2012].groupby("state_code")[["varroa_per_100_bees", "million_spores_per_bee"]].mean()\
.sort_values(["varroa_per_100_bees","million_spores_per_bee"] , ascending = [False, False]).plot.bar()
# Out:
# <AxesSubplot:xlabel='state_code'>

# %%
df[df.year.dt.year == 2013].groupby("state_code")[["varroa_per_100_bees", "million_spores_per_bee"]].mean()\
.sort_values(["varroa_per_100_bees","million_spores_per_bee"] , ascending = [False, False]).plot.bar()
# Out:
# <AxesSubplot:xlabel='state_code'>

# %%
df[df.year.dt.year == 2014].groupby("state_code")[["varroa_per_100_bees", "million_spores_per_bee"]].mean()\
.sort_values(["varroa_per_100_bees","million_spores_per_bee"] , ascending = [False, False]).plot.bar()
# Out:
# <AxesSubplot:xlabel='state_code'>

# %%
df[df.year.dt.year == 2015].groupby("state_code")[["varroa_per_100_bees", "million_spores_per_bee"]].mean()\
.sort_values(["varroa_per_100_bees","million_spores_per_bee"] , ascending = [False, False]).plot.bar()
# Out:
# <AxesSubplot:xlabel='state_code'>

# %%
df = pd.read_csv("Data/df_st.csv")
state_code = list(df.state_code)
combined_df = pd.DataFrame()
for state in state_code:
    temp_df = df[df.state_code == state].T
    temp_df.columns = ['mites']
    temp_df['state'] = state
    temp_df = temp_df.iloc[1:, :]
    combined_df = combined_df.append(temp_df)

# %%
pd.read_csv("Data/df_st.csv").head()
# Out:
#   state_code  2011-12-31  2012-12-31  2013-12-31  2014-12-31  2015-12-31  \
# 0         AK         NaN         NaN         NaN         NaN         NaN
# 1         AL    7.364000    7.295833   10.889231    4.009091    3.521852
# 2         AR    4.008000    6.612500    3.927917    5.664583    3.102174
# 3         CA    1.696667    1.965778    1.628409    1.654167    1.199091
# 4         CO   10.405263    2.077778    1.862500         NaN         NaN
#
#    2016-12-31  2017-12-31  2018-12-31  2019-12-31  2020-12-31
# 0         NaN         NaN    1.176000    0.654000         NaN
# 1    3.104074    4.903000    3.915833    5.280000    2.905217
# 2         NaN    2.747917    5.167619    4.383571    3.783750
# 3    1.184773    1.169677    1.743333    1.358158    0.912647
# 4    3.175263    1.224286    2.252500         NaN         NaN

# %%
combined_df
# Out:
#                mites state
# 2011-12-31       NaN    AK
# 2012-12-31       NaN    AK
# 2013-12-31       NaN    AK
# 2014-12-31       NaN    AK
# 2015-12-31       NaN    AK
# ...              ...   ...
# 2016-12-31  4.315833    WV
# 2017-12-31   5.09375    WV
# 2018-12-31    1.9475    WV
# 2019-12-31  4.464074    WV
# 2020-12-31    2.2475    WV
#
# [500 rows x 2 columns]
